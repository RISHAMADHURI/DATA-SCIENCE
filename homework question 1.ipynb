# %%
import pandas as pd

# %%
 data ={
     'Employee ID': [1, 2, 3, 4, 5],
'Name':['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
'Department':['HR', 'IT', 'Finance', 'HR', 'IT'],
'Salary':[50000, 60000, 55000, 52000, 62000]
 }

# %%
data
# Out:
# {'Employee ID': [1, 2, 3, 4, 5],
#  'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
#  'Department': ['HR', 'IT', 'Finance', 'HR', 'IT'],
#  'Salary': [50000, 60000, 55000, 52000, 62000]}

# %%
df = pd.DataFrame(data)
df
# Out:
#    Employee ID     Name Department  Salary
# 0            1    Alice         HR   50000
# 1            2      Bob         IT   60000
# 2            3  Charlie    Finance   55000
# 3            4    David         HR   52000
# 4            5      Eve         IT   62000

# %%
df.head()
# Out:
#    Employee ID     Name Department  Salary
# 0            1    Alice         HR   50000
# 1            2      Bob         IT   60000
# 2            3  Charlie    Finance   55000
# 3            4    David         HR   52000
# 4            5      Eve         IT   62000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Employee ID  5 non-null      int64
#  1   Name         5 non-null      object
#  2   Department   5 non-null      object
#  3   Salary       5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes

# %%
df.describe()
# Out:
#        Employee ID        Salary
# count     5.000000      5.000000
# mean      3.000000  55800.000000
# std       1.581139   5118.593557
# min       1.000000  50000.000000
# 25%       2.000000  52000.000000
# 50%       3.000000  55000.000000
# 75%       4.000000  60000.000000
# max       5.000000  62000.000000
